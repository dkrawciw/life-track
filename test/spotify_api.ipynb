# %%
from pathlib import Path
import spotipy
from spotipy.oauth2 import SpotifyOAuth, SpotifyClientCredentials
from dotenv import load_dotenv
import os

PARENT_DIR = Path('.').parent.parent
load_dotenv(dotenv_path=PARENT_DIR / ".env")

SPOTIPY_CLIENT_ID = os.getenv('SPOTIPY_CLIENT_ID')
SPOTIPY_CLIENT_SECRET = os.getenv('SPOTIPY_CLIENT_SECRET')
SPOTIPY_REDIRECT_URI = os.getenv('SPOTIPY_REDIRECT_URI')
TRUTH_UNITES_CODE = "5pwOh3BIp7rQaeZpmy8SF8"

# %%
scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET))

results = sp.current_user_saved_tracks()
# Out:
# Opening in existing browser session.

# %%
print(results.keys())
# Out:
# href
# items
# limit
# next
# offset
# previous
# total

# %%
for item in results["items"]:
    print(item["track"]['name'])
    for artist in item['track']['artists']:
        print(artist['name'])
    
    print("\n")
# Out:
# Rejoice
# Andrew Peterson
#
#
# WHY (feat. Luke Combs)
# Jon Bellion
# Luke Combs
#
#
# Somewhere Only We Know
# Keane
#
#
# Not Too Late
# Andy Gullahorn
#
#
# Psalm 18
# Poor Bishop Hooper
#
#
# Sapphire
# Ed Sheeran
#
#
# Old Phone
# Ed Sheeran
#
#
# Closer Than A Brother
# Josh Garrels
#
#
# Shine
# The Gray Havens
#
#
# Belly Button
# VeggieTales
#
#
# Adam, Check Please
# Owl City
#
#
# Dreams Don't Turn To Dust
# Owl City
#
#
# Kelly Time
# Owl City
#
#
# Blue Over You
# Mason Ramsey
#
#
# What Was
# Benson Boone
#
#
# Ordinary Miracle
# The Gray Havens
#
#
# Iroh's Tsungi Horn
# Jeremy Zuckerman
#
#
# Katara
# Jeremy Zuckerman
#
#
# Spider-Woman (Gwen Stacy)
# Daniel Pemberton
#
#
# Miles Morales Returns
# Daniel Pemberton

# %%
scope = "user-read-playback-position"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET))

results = sp.show_episodes(show_id=TRUTH_UNITES_CODE)
# Out:
# Opening in existing browser session.

# %%
results['items'][0]
# Out:
# {'audio_preview_url': 'https://podz-content.spotifycdn.com/audio/clips/6hATV2A6LCHN8L34avw8NN/clip_171000_232320.mp3',
#  'description': 'Gavin Ortlund describes how infant baptism may have arisen in the early church from a credobapist perspective.Truth Unites (https://truthunites.org) exists to promote gospel assurance through theological depth. Gavin Ortlund (PhD, Fuller Theological Seminary) is President of Truth Unites, Visiting Professor of Historical Theology at Phoenix Seminary, and Theologian-in-Residence at Immanuel Nashville.SUPPORT:Tax Deductible Support: https://truthunites.org/donate/Patreon: https://www.patreon.com/truthunitesFOLLOW:Website: https://truthunites.org/Instagram: https://www.instagram.com/truth.unites/Twitter: https://twitter.com/gavinortlundFacebook: https://www.facebook.com/TruthUnitesPage/',
#  'duration_ms': 3528888,
#  'explicit': False,
#  'external_urls': {'spotify': 'https://open.spotify.com/episode/2zMNSKq4GLKnUDcrfO1JY3'},
# ...

# %%
for show in results['items']:
    print(show['name'])
    print(f"Released on: {show['release_date']}")
    print(show["uri"])
    print(f"Played Duration: {show['resume_point']['resume_position_ms']} ms")
    print("\n")
# Out:
# How Did Infant Baptism Begin? A Story of Five Centuries of Church History
# Released on: 2025-07-07
# spotify:episode:2zMNSKq4GLKnUDcrfO1JY3
# Played Duration: 2608000 ms
#
#
# How Rebuttals Go Wrong: Joe Heschmeyer and the Canon Debate
# Released on: 2025-07-04
# spotify:episode:5ewWNNUop5vpfogqYHBPE2
# Played Duration: 0 ms
#
#
# Is the Book of Job Evil?
# Released on: 2025-07-02
# spotify:episode:1u2qsyDd5i3HMKXrOOAMjN
# Played Duration: 0 ms
#
#
# Do Muslims and Christians Worship the Same God?
# Released on: 2025-06-27
# spotify:episode:28r91pYNlg7rT99JbyzYyn
# Played Duration: 0 ms
#
#
# The Protestant Canon Defended (With Javier Perdomo and Cleave to Antiquity)
# Released on: 2025-06-25
# spotify:episode:474aOti4yjH26sMGc32EBi
# Played Duration: 0 ms
#
#
# Best Evidence for Jesus OUTSIDE the Bible (With Tom Schmidt)
# Released on: 2025-06-23
# spotify:episode:0BkYiuRYIZyxOlLFpc7FXO
# Played Duration: 1002000 ms
#
#
# ...

# %%
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET))
show_info = sp.show(TRUTH_UNITES_CODE)

# %%
print(f"{show_info['name']} by {show_info['publisher']}")
print(f"Total # of Episodes: {show_info['total_episodes']}")
# Out:
# Truth Unites by Gavin Ortlund
# Total # of Episodes: 294
